# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/daily_codes/week2/list_june1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l= [23,45,76,89,12]

# %%
print(l)
# Out:
# [23, 45, 76, 89, 12]

# %%
# lists are heterogenous and duplicates are also allowed

# %%
l=[23,45,67,90,89,12,"python","java",23,45]

# %%
l
# Out:
# [23, 45, 67, 90, 89, 12, 'python', 'java', 23, 45]

# %%
# lists are ordered

# %%
l[2]
# Out:
# 67

# %%
l[-3]
# Out:
# 'java'

# %%
l[1]
# Out:
# 45

# %%
l[1]=100

# %%
l[1]
# Out:
# 100

# %%
l
# Out:
# [23, 100, 67, 90, 89, 12, 'python', 'java', 23, 45]

# %%
l[-3]
# Out:
# 'java'

# %%
l[-3]= True

# %%
l[-3]
# Out:
# True

# %%
l
# Out:
# [23, 100, 67, 90, 89, 12, 'python', True, 23, 45]

# %%
# list slicing

# %%
l=[21,23,45,67,89,11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l [1:4]
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
# 21,45,89

# %%
l[0:6:2]
# Out:
# [21, 45, 89]

# %%
l[::2]
# Out:
# [21, 45, 89]

# %%
#reverse the list

# %%
l[::1]
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l[1:4]=[100,200,300]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
del l[-2]

# %%
l
# Out:
# [21, 100, 200, 300, 11]

# %%
l1=[12,53,35,74]

# %%
l1
# Out:
# [12, 53, 35, 74]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 53, 74]

# %%
del l1

# %%
# membership operator

# %%
l
# Out:
# [21, 100, 200, 300, 11]

# %%
89 in l
# Out:
# False

# %%
300 in l
# Out:
# True

# %%
# arithmetic operator

# %%
l
# Out:
# [21, 100, 200, 300, 11]

# %%
l * 2  #repetition of list
# Out:
# [21, 100, 200, 300, 11, 21, 100, 200, 300, 11]

# %%
"ok"* 3 # string repitition
# Out:
# 'okokok'

# %%
l + [60,70,80]
# Out:
# [21, 100, 200, 300, 11, 60, 70, 80]

# %%
# take 2 different list and add them

# %%
l2=[33,65,24,86]

# %%
l3=[54,35,82,74]

# %%
l2 + l3
# Out:
# [33, 65, 24, 86, 54, 35, 82, 74]

# %%
# iteration over list

# %%
l
# Out:
# [21, 100, 200, 300, 11]

# %%
#iterate over list and print square of each element

# %%
for i in l:
  print(i**2, end = ' ')
# Out:
# 441 10000 40000 90000 121

# %%
# print odd number in the list

# %%
for i in l:
    if i % 2 != 0:
        print(i, )
# Out:
# 21
# 11

# %%
# list comprehension-> [ expression for_loop if_condition]

# %%
newl= [i**2 for i in l]

# %%
newl
# Out:
# [441, 10000, 40000, 90000, 121]

# %%
newl2= [i for i in l if i%2==1]

# %%
newl2
# Out:
# [21, 11]

# %%
names=['aryan','atharva', 'samruddhi', 'swaraj','Sukanya','shivraj']

# %%
names
# Out:
# ['aryan', 'atharva', 'samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
# create a new list with the names starts with 's' or 'S'

# %%
newl3= [name for name in names if name.startswith('s') or name.startswith('S')]

# %%
newl3
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
for i in names:
  if i.lower().startswith('s'):
    print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# shivraj

# %%
newl4=[i for i in names if i.lower().startswith('s')]

# %%
newl4
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
len(l)
# Out:
# 5

# %%
max(l)
# Out:
# 300

# %%
min(l)
# Out:
# 11

# %%
sorted(l)
# Out:
# [11, 21, 100, 200, 300]

# %%
sorted(l,reverse=True)
# Out:
# [300, 200, 100, 21, 11]

# %%
# list methods

# %%
# append

# %%
l
# Out:
# [21, 100, 200, 300, 11]

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 11, 1000]

# %%
l1=[1,2,3]
l2=[1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1]=323

# %%
l1
# Out:
# [1, 2, 3, [100, 323]]

# %%
l
# Out:
# [21, 100, 200, 300, 11, 1000]

# %%
l.insert(1,70)

# %%
l
# Out:
# [21, 70, 100, 200, 300, 11, 1000]

# %%
l.remove(70)

# %%
l
# Out:
# [21, 100, 200, 300, 11, 1000]

# %%
# pop

# %%
l.pop()
# Out:
# 1000

# %%
l.pop(2)
# Out:
# 200

# %%
l.index(300)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [11, 21, 100, 300]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [300, 100, 21, 11]
