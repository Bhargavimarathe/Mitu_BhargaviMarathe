# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/Mitu_BhargaviMarathe/blob/main/basic_may_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
#string

# %%
name= "bhargavi"

# %%
name.lower()
# Out:
# 'bhargavi'

# %%
name = name.lower()

# %%
name
# Out:
# 'bhargavi'

# %%
name.upper()
# Out:
# 'BHARGAVI'

# %%
name.title()
# Out:
# 'Bhargavi'

# %%
name = "Bhargavi"

# %%
name.swapcase()
# Out:
# 'bHARGAVI'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name2.isalnum()
# Out:
# True

# %%
name3.isalnum()
# Out:
# True

# %%
name = "Pune"

# %%
print(name)
# Out:
# Pune

# %%
name.startswith("p")
# Out:
# False

# %%
name.startswith(" Pune ")
# Out:
# False

# %%
name.endswith(" Pune ")
# Out:
# False

# %%
name.endswith("Pune")
# Out:
# True

# %%
name.endswith("e")
# Out:
# True

# %%
name = " pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith(" ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'pune '

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u','oo')
# Out:
# ' poone '

# %%
#arithmetic

# %%
a=5
b=17

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
b/a
# Out:
# 3.4

# %%
a * b
# Out:
# 85

# %%
a**b # raise to
# Out:
# 762939453125

# %%
a%b
# Out:
# 5

# %%
b // a
# Out:
# 3

# %%
b % a
# Out:
# 2

# %%
# assignment operator

# %%
z=5

# %%
z
# Out:
# 5

# %%
z= z+3

# %%
z
# Out:
# 8

# %%
z+=3

# %%
z
# Out:
# 11

# %%
z-=3

# %%
z
# Out:
# 8

# %%
z*=3
z
# Out:
# 24

# %%
z+=4

# %%
z
# Out:
# 4.0

# %%
#comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a==b
# Out:
# True

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
a=5
a
# Out:
# 5

# %%
b=8
b
# Out:
# 8

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
# logical operator

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operator

# %%
a = 5

# %%
b= 5

# %%
id(a), id(b)
# Out:
# (11645480, 11645480)

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
a= [ 3, 4]
b= [ 3, 4]

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
id(a), id(b)
# Out:
# (133201487472256, 133201487476416)

# %%
z= a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)

# %%
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
#membership operator

# %%
l = [4,6,19,10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
6 not in l
# Out:
# False

# %%
2 not in l
# Out:
# True

# %%
## Precedence and association

# %%
# BODMAS

# %%
5+2-10
# Out:
# -3

# %%
(4 - 2)** 2
# Out:
# 4

# %%
2 ** 2** 3 # RIGHT ASSOCIATION
# Out:
# 256

# %%
2**3/ 2
# Out:
# 4.0

# %%
name = "geet"

# %%
marks = 76.57

# %%
print("my name is ",name,"and marks are",marks)
# Out:
# my name is  geet and marks are 76.57

# %%
print("my name is %s and marks are %i" %(name,marks))
# Out:
# my name is geet and marks are 76

# %%
print(f"my name is {name} and makrs are {marks}")
# Out:
# my name is geet and makrs are 76.57

# %%
seconds = int(input("Enter time in seconds: "))
# Out:
# Enter time in seconds: 653

# %%
hours = seconds // 3600
minutes = (seconds % 3600) // 60
seconds = seconds % 60

# %%
print(f"{hours}:{minutes}:{seconds}")
# Out:
# 0:10:53
