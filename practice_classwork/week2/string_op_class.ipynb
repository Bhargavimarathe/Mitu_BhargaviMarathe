# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/practice_classwork/week2/string_op_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a Python function that takes a string as input. Using a for loop, iterate through each character.
#If the character is a vowel (a, e, i, o, u, case-insensitive), increment a counter.
 #Store the count of each vowel in a dictionary.
#Finally, print the total number of vowels found and the dictionary of vowel counts.

# %%
def vowel_counter():
    s = input("Enter a string: ")

    vowels = {'a':0, 'e':0, 'i':0, 'o':0, 'u':0}
    total = 0

    for ch in s.lower():
        if ch in vowels:
            vowels[ch] += 1
            total += 1

    print("Vowels are:", vowels)
    print("Total vowels:", total)

vowel_counter()
# Out:
# Enter a string: bhargavi
# Vowels are: {'a': 2, 'e': 0, 'i': 1, 'o': 0, 'u': 0}
# Total vowels: 3

# %%
#Write a Python function that accepts a string. Inside the function, use a for loop to build a new list containing
#the characters of the string in reverse order. Then, use an if-else statement to
#check if the original string is a palindrome (reads the same forwards and backward) by comparing it to the string formed from the reversed list.
#print whether the string is a palindrome or not.

# %%
def palindrome_check():
    s = input("Enter the string: ")

    rev_list = []

    for ch in s:
        rev_list.insert(0, ch)

    rev_str = "".join(rev_list)

    if s == rev_str:
        print("Palindrome")
    else:
        print("Not Palindrome")

palindrome_check()
# Out:
# Enter the string: bhargavi
# Not Palindrome

# %%
#Create a Python function that takes a string.
#Use a for loop to iterate through the string and populate a dictionary where keys are characters and values are their frequencies.
 #Use an if-else statement to handle whether a character is already in the dictionary or not.
 #Print the resulting character frequency dictionary.

# %%
def char_frequency():
    s = input("Enter a string: ")

    freq = {}

    for ch in s:
        if ch in freq:
            freq[ch] += 1
        else:
            freq[ch] = 1

    print("Character Frequency Dictionary:")
    print(freq)

char_frequency()
# Out:
# Enter a string: bhargavi
# Character Frequency Dictionary:
# {'b': 1, 'h': 1, 'a': 2, 'r': 1, 'g': 1, 'v': 1, 'i': 1}

# %%
#Write a Python function that takes a sentence (string) as input. Split the sentence into words. Using a for loop, iterate through each word. Use if-elif-else statements to classify words as:

#short (length < 5)
#medium (5 <= length <= 8)
#long (length > 8)

#Store these classified words in separate lists (short_words, medium_words, long_words). Print all three lists.

def classify_words():
    sentence = input("Enter a sentence: ")

    short_words = []
    medium_words = []
    long_words = []

    words = sentence.split()

    for word in words:
        if len(word) < 5:
            short_words.append(word)
        elif len(word) <= 8:
            medium_words.append(word)
        else:
            long_words.append(word)

    print("Short words:", short_words)
    print("Medium words:", medium_words)
    print("Long words:", long_words)

classify_words()
# Out:
# Enter a sentence: i like python programming
# Short words: ['i', 'like']
# Medium words: ['python']
# Long words: ['programming']

# %%
#Given a list of strings, write a function that iterates through each string.
# If a string starts with a specific prefix (e.g., "py") and ends with a specific suffix (e.g., "thon"),
# add it to a new list called matching_strings. Use an if statement to check the conditions. Print the matching_strings list.

def matching_strings():
    l = ["python", "pythons", "pyathon", "java", "py123thon"]

    result = []

    for s in l:
        if s.startswith("py") and s.endswith("thon"):
            result.append(s)

    print("Matching Strings:", result)

matching_strings()
# Out:
# Matching Strings: ['python', 'pyathon', 'py123thon']

# %%
# Write a function that takes a paragraph (string) as input. Convert the paragraph to lowercase and remove punctuation.
 #Use a for loop to split the paragraph into words and add each unique word to a set data structure.
 # Finally, convert the set back to a sorted list and print it.

def unique_words():
    p = input("Enter a paragraph: ")

    words = p.lower().split()
    s = set()

    for word in words:
        s.add(word)

    print(sorted(s))

unique_words()
# Out:
# Enter a paragraph: my name is bhargavi sudhir marathe , i am studying in pimpri chinchwad polytechnic college and i am a TY student at IF dept
# [',', 'a', 'am', 'and', 'at', 'bhargavi', 'chinchwad', 'college', 'dept', 'i', 'if', 'in', 'is', 'marathe', 'my', 'name', 'pimpri', 'polytechnic', 'student', 'studying', 'sudhir', 'ty']

# %%
#Create a Python function that takes a string. Using a for loop with enumerate, iterate through the string.
 #Use an if-else statement to check if the index of a character is even or odd.
 #Store characters at even indices in one list and characters at odd indices in another list. Print both lists.

def separate_chars():
    s = input("Enter a string: ")

    even = []
    odd = []

    for i, ch in enumerate(s):
        if i % 2 == 0:
            even.append(ch)
        else:
            odd.append(ch)

    print("Even:", even)
    print("Odd:", odd)

separate_chars()
# Out:
# Enter a string: bhargavi
# Even: ['b', 'a', 'g', 'v']
# Odd: ['h', 'r', 'a', 'i']
