# %%
print("Hello world")
# Out:
# Hello world

# %%
num=24
num1 = 3

# %%
print(num)
# Out:
# 24

# %%
print(num1)
# Out:
# 3

# %%
num2=num1+num
print(num2)
# Out:
# 27

# %%
name="bhargavi"

# %%
print(name)
# Out:
# bhargavi

# %%
num = 28

# %%
num1= 35.6

# %%
num2= "bhargavi"

# %%
type(num)
# Out:
# int

# %%
type(num2)
# Out:
# str

# %%
a,b,c = 2,3,"ok"

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3

# %%
c
# Out:
# 'ok'

# %%
num=2345**455

# %%
num
# Out:
# ...

# %%
num = 23e4

# %%
num
# Out:
# 230000.0

# %%
type(num)
# Out:
# float

# %%
sent = "I like python programming "

# %%
print(sent)
# Out:
# I like python programming

# %%
sent = 'I like "python" programming'

# %%
print(sent)
# Out:
# I like "python" programming

# %%
sent = "I like 'python' programming"

# %%
print(sent)
# Out:
# I like 'python' programming

# %%
a= 2
b= 3
z = a+b
print(z)
# Out:
# 5

# %%
a=2; b=4; c=a+b;
print(c)
# Out:
# 6

# %%
a,b,c = 2,3,"ok"

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3

# %%
c
# Out:
# 'ok'
